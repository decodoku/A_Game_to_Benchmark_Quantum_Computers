# %% [markdown]
# ## Set up and execute a calls to `GetData()` function

# %%
from devices import supportedDevices, getLayout
from QuantumAwesomeness import *

# %% [markdown]
# Specify the device you want to use (*device*) and whether you want data for a simulation, the real device, or both (*sims_to_use*).

# %%
device = 'ibmqx4'
sims_to_use = [False]

# %% [markdown]
# Get the data for the requested instances.

# %%
num, area, entangleType, pairs, pos, example, sdk, runs = getLayout(device)

for sim in sims_to_use:
    for move in runs[sim]['move']:
        for shots in runs[sim]['shots']:
            GetData( device, move, shots, sim, runs[sim]['samples'], runs[sim]['maxScore'] )
# Out:
# move=C, shots=100, sample=1
# move=C, shots=100, sample=2
# move=C, shots=100, sample=3
# move=C, shots=100, sample=4
# move=C, shots=100, sample=5
# move=C, shots=100, sample=6
# move=C, shots=100, sample=7
# move=C, shots=100, sample=8
# move=C, shots=100, sample=9
# move=C, shots=100, sample=10
# move=C, shots=100, sample=11
# move=C, shots=100, sample=12
# move=C, shots=100, sample=13
# move=C, shots=100, sample=14
# move=C, shots=100, sample=15
# move=C, shots=100, sample=16
# move=C, shots=100, sample=17
# move=C, shots=100, sample=18
# move=C, shots=100, sample=19
# move=C, shots=100, sample=20
# move=C, shots=100, sample=21
# move=C, shots=100, sample=22
# move=C, shots=100, sample=23
# move=C, shots=100, sample=24
# move=C, shots=100, sample=25
# move=C, shots=100, sample=26
# move=C, shots=100, sample=27
# move=C, shots=100, sample=28
# move=C, shots=100, sample=29
# move=C, shots=100, sample=30
# move=C, shots=100, sample=31
# move=C, shots=100, sample=32
# move=C, shots=100, sample=33
# move=C, shots=100, sample=34
# move=C, shots=100, sample=35
# move=C, shots=100, sample=36
# move=C, shots=100, sample=37
# move=C, shots=100, sample=38
# move=C, shots=100, sample=39
# move=C, shots=100, sample=40
# move=C, shots=100, sample=41
# move=C, shots=100, sample=42
# move=C, shots=100, sample=43
# move=C, shots=100, sample=44
# move=C, shots=100, sample=45
# move=C, shots=100, sample=46
# move=C, shots=100, sample=47
# move=C, shots=100, sample=48
# move=C, shots=100, sample=49
# move=C, shots=100, sample=50
# move=C, shots=100, sample=51
# move=C, shots=100, sample=52
# move=C, shots=100, sample=53
# move=C, shots=100, sample=54
# move=C, shots=100, sample=55
# move=C, shots=100, sample=56
# move=C, shots=100, sample=57
# move=C, shots=100, sample=58
# move=C, shots=100, sample=59
# move=C, shots=100, sample=60
# move=C, shots=100, sample=61
# move=C, shots=100, sample=62
# move=C, shots=100, sample=63
# move=C, shots=100, sample=64
# move=C, shots=100, sample=65
# move=C, shots=100, sample=66
# move=C, shots=100, sample=67
# move=C, shots=100, sample=68
# move=C, shots=100, sample=69
# move=C, shots=100, sample=70
# move=C, shots=100, sample=71
# move=C, shots=100, sample=72
# move=C, shots=100, sample=73
# move=C, shots=100, sample=74
# move=C, shots=100, sample=75
# move=C, shots=100, sample=76
# move=C, shots=100, sample=77
# move=C, shots=100, sample=78
# move=C, shots=100, sample=79
# move=C, shots=100, sample=80
# move=C, shots=100, sample=81
# move=C, shots=100, sample=82
# move=C, shots=100, sample=83
# move=C, shots=100, sample=84
# move=C, shots=100, sample=85
# move=C, shots=100, sample=86
# move=C, shots=100, sample=87
# move=C, shots=100, sample=88
# move=C, shots=100, sample=89
# move=C, shots=100, sample=90
# move=C, shots=100, sample=91
# move=C, shots=100, sample=92
# move=C, shots=100, sample=93
# move=C, shots=100, sample=94
# move=C, shots=100, sample=95
# move=C, shots=100, sample=96
# move=C, shots=100, sample=97
# move=C, shots=100, sample=98
# move=C, shots=100, sample=99
# move=C, shots=100, sample=100
# move=C, shots=8192, sample=1
# move=C, shots=8192, sample=2
# move=C, shots=8192, sample=3
# move=C, shots=8192, sample=4
# move=C, shots=8192, sample=5
# move=C, shots=8192, sample=6
# move=C, shots=8192, sample=7
# move=C, shots=8192, sample=8
# move=C, shots=8192, sample=9
# move=C, shots=8192, sample=10
# move=C, shots=8192, sample=11
# move=C, shots=8192, sample=12
# move=C, shots=8192, sample=13
# move=C, shots=8192, sample=14
# move=C, shots=8192, sample=15
# move=C, shots=8192, sample=16
# move=C, shots=8192, sample=17
# move=C, shots=8192, sample=18
# move=C, shots=8192, sample=19
# move=C, shots=8192, sample=20
# move=C, shots=8192, sample=21
# move=C, shots=8192, sample=22
# move=C, shots=8192, sample=23
# move=C, shots=8192, sample=24
# move=C, shots=8192, sample=25
# move=C, shots=8192, sample=26
# move=C, shots=8192, sample=27
# move=C, shots=8192, sample=28
# move=C, shots=8192, sample=29
# move=C, shots=8192, sample=30
# move=C, shots=8192, sample=31
# move=C, shots=8192, sample=32
# move=C, shots=8192, sample=33
# move=C, shots=8192, sample=34
# move=C, shots=8192, sample=35
# move=C, shots=8192, sample=36
# move=C, shots=8192, sample=37
# move=C, shots=8192, sample=38
# move=C, shots=8192, sample=39
# move=C, shots=8192, sample=40
# move=C, shots=8192, sample=41
# move=C, shots=8192, sample=42
# move=C, shots=8192, sample=43
# move=C, shots=8192, sample=44
# move=C, shots=8192, sample=45
# move=C, shots=8192, sample=46
# move=C, shots=8192, sample=47
# move=C, shots=8192, sample=48
# move=C, shots=8192, sample=49
# move=C, shots=8192, sample=50
# move=C, shots=8192, sample=51
# move=C, shots=8192, sample=52
# move=C, shots=8192, sample=53
# move=C, shots=8192, sample=54
# move=C, shots=8192, sample=55
# move=C, shots=8192, sample=56
# move=C, shots=8192, sample=57
# move=C, shots=8192, sample=58
# move=C, shots=8192, sample=59
# move=C, shots=8192, sample=60
# move=C, shots=8192, sample=61
# move=C, shots=8192, sample=62
# move=C, shots=8192, sample=63
# move=C, shots=8192, sample=64
# move=C, shots=8192, sample=65
# move=C, shots=8192, sample=66
# move=C, shots=8192, sample=67
# move=C, shots=8192, sample=68
# move=C, shots=8192, sample=69
# move=C, shots=8192, sample=70
# move=C, shots=8192, sample=71
# move=C, shots=8192, sample=72
# move=C, shots=8192, sample=73
# move=C, shots=8192, sample=74
# move=C, shots=8192, sample=75
# move=C, shots=8192, sample=76
# move=C, shots=8192, sample=77
# move=C, shots=8192, sample=78
# move=C, shots=8192, sample=79
# move=C, shots=8192, sample=80
# move=C, shots=8192, sample=81
# move=C, shots=8192, sample=82
# move=C, shots=8192, sample=83
# move=C, shots=8192, sample=84
# move=C, shots=8192, sample=85
# move=C, shots=8192, sample=86
# move=C, shots=8192, sample=87
# move=C, shots=8192, sample=88
# move=C, shots=8192, sample=89
# move=C, shots=8192, sample=90
# move=C, shots=8192, sample=91
# move=C, shots=8192, sample=92
# move=C, shots=8192, sample=93
# move=C, shots=8192, sample=94
# move=C, shots=8192, sample=95
# move=C, shots=8192, sample=96
# move=C, shots=8192, sample=97
# move=C, shots=8192, sample=98
# move=C, shots=8192, sample=99
# move=C, shots=8192, sample=100
# move=R, shots=100, sample=1
# move=R, shots=100, sample=2
# move=R, shots=100, sample=3
# move=R, shots=100, sample=4
# move=R, shots=100, sample=5
# move=R, shots=100, sample=6
# move=R, shots=100, sample=7
# move=R, shots=100, sample=8
# move=R, shots=100, sample=9
# move=R, shots=100, sample=10
# move=R, shots=100, sample=11
# move=R, shots=100, sample=12
# move=R, shots=100, sample=13
# move=R, shots=100, sample=14
# move=R, shots=100, sample=15
# move=R, shots=100, sample=16
# move=R, shots=100, sample=17
# move=R, shots=100, sample=18
# move=R, shots=100, sample=19
# move=R, shots=100, sample=20
# move=R, shots=100, sample=21
# move=R, shots=100, sample=22
# move=R, shots=100, sample=23
# move=R, shots=100, sample=24
# move=R, shots=100, sample=25
# move=R, shots=100, sample=26
# move=R, shots=100, sample=27
# move=R, shots=100, sample=28
# move=R, shots=100, sample=29
# move=R, shots=100, sample=30
# move=R, shots=100, sample=31
# move=R, shots=100, sample=32
# move=R, shots=100, sample=33
# move=R, shots=100, sample=34
# move=R, shots=100, sample=35
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /home/james/anaconda3/lib/python3.6/site-packages/IBMQuantumExperience/IBMQuantumExperience.py in obtain_token(self, config)
#     172         try:
# --> 173             response.raise_for_status()
#     174             self.data_credentials = response.json()
#
# /home/james/anaconda3/lib/python3.6/site-packages/requests/models.py in raise_for_status(self)
#     934         if http_error_msg:
# --> 935             raise HTTPError(http_error_msg, response=self)
#     936
#
# HTTPError: 502 Server Error: Bad Gateway for url: https://quantumexperience.ng.bluemix.net/api/users/loginWithToken
#
# During handling of the above exception, another exception occurred:
#
# ApiError                                  Traceback (most recent call last)
# /home/james/anaconda3/lib/python3.6/site-packages/qiskit/backends/ibmq/ibmqprovider.py in _authenticate(cls, token, url, hub, group, project, proxies, verify)
#      87                 config_dict['proxies'] = proxies
# ---> 88             return IBMQuantumExperience(token, config_dict, verify)
#      89         except Exception as ex:
#
# /home/james/anaconda3/lib/python3.6/site-packages/IBMQuantumExperience/IBMQuantumExperience.py in __init__(self, token, config, verify)
#     460         self.config = config
# --> 461         self.req = _Request(token, config=config, verify=verify)
#     462
#
# /home/james/anaconda3/lib/python3.6/site-packages/IBMQuantumExperience/IBMQuantumExperience.py in __init__(self, token, config, verify, retries, timeout_interval)
#     261                                        proxy_urls=self.proxy_urls,
# --> 262                                        ntlm_credentials=self.ntlm_credentials)
#     263         self.log = logging.getLogger(__name__)
#
# /home/james/anaconda3/lib/python3.6/site-packages/IBMQuantumExperience/IBMQuantumExperience.py in __init__(self, token, config, verify, proxy_urls, ntlm_credentials)
#     104         if token:
# --> 105             self.obtain_token(config=self.config)
#     106         else:
#
# /home/james/anaconda3/lib/python3.6/site-packages/IBMQuantumExperience/IBMQuantumExperience.py in obtain_token(self, config)
#     175         except (requests.HTTPError, ValueError) as e:
# --> 176             raise ApiError('error during login: %s' % str(e))
#     177
#
# ApiError: error during login: 502 Server Error: Bad Gateway for url: https://quantumexperience.ng.bluemix.net/api/users/loginWithToken
#
# The above exception was the direct cause of the following exception:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-3-0727c33ecb04> in <module>()
#       4     for move in runs[sim]['move']:
#       5         for shots in runs[sim]['shots']:
# ----> 6             GetData( device, move, shots, sim, runs[sim]['samples'], runs[sim]['maxScore'] )
#
# /home/james/Dropbox/Work/Programming/A_Game_to_Benchmark_Quantum_Computers/QuantumAwesomeness.py in GetData(device, move, shots, sim, samples, maxScore)
#     879         print("move="+move+", shots="+str(shots)+", sample=" + str(sample+1) )
#     880
# --> 881         gates, conjugates, oneProbs, sameProbs, resultsDicts = runGame( device, move, shots, sim, maxScore )
#     882
#     883         # make a directory for this device if it doesn't already exist
#
# /home/james/Dropbox/Work/Programming/A_Game_to_Benchmark_Quantum_Computers/QuantumAwesomeness.py in runGame(device, move, shots, sim, maxScore, dataNeeded, clean, game)
#     676
#     677             # all gates so far are then run
# --> 678             oneProb, sameProb, results = entangle( device, move, shots, sim, gates, conjugates)
#     679
#     680         else:
#
# /home/james/Dropbox/Work/Programming/A_Game_to_Benchmark_Quantum_Computers/QuantumAwesomeness.py in entangle(device, move, shots, sim, gates, conjugates)
#     351     num, area, entangleType, pairs, pos, example, sdk, runs = getLayout(device)
#     352
# --> 353     q, c, engine, script = initializeQuantumProgram(device,sim)
#     354
#     355     # apply all gates
#
# /home/james/Dropbox/Work/Programming/A_Game_to_Benchmark_Quantum_Computers/QuantumAwesomeness.py in initializeQuantumProgram(device, sim)
#      58     num, area, entangleType, pairs, pos, example, sdk, runs = getLayout(device)
#      59
# ---> 60     importSDK ( device )
#      61
#      62     if sdk in ["QISKit","ManualQISKit"]:
#
# /home/james/Dropbox/Work/Programming/A_Game_to_Benchmark_Quantum_Computers/QuantumAwesomeness.py in importSDK(device)
#      28             "APItoken": Qconfig.APItoken,
#      29             "url": Qconfig.config['url']}
# ---> 30         register(qx_config['APItoken'], qx_config['url'])
#      31     elif sdk=="ProjectQ":
#      32         global projectq, H, Measure, CNOT, C, Z, Rx, Ry
#
# /home/james/anaconda3/lib/python3.6/site-packages/qiskit/wrapper/_wrapper.py in register(token, url, hub, group, project, proxies, verify, provider_name)
#      56     if provider_name == 'ibmq':
#      57         provider = IBMQProvider(token, url,
# ---> 58                                 hub, group, project, proxies, verify)
#      59         _DEFAULT_PROVIDER.add_provider(provider)
#      60     else:
#
# /home/james/anaconda3/lib/python3.6/site-packages/qiskit/backends/ibmq/ibmqprovider.py in __init__(self, token, url, hub, group, project, proxies, verify)
#      32         # Get a connection to IBMQuantumExperience.
#      33         self._api = self._authenticate(token, url,
# ---> 34                                        hub, group, project, proxies, verify)
#      35
#      36         # Populate the list of remote backends.
#
# /home/james/anaconda3/lib/python3.6/site-packages/qiskit/backends/ibmq/ibmqprovider.py in _authenticate(cls, token, url, hub, group, project, proxies, verify)
#      94                 root_exception = None
#      95             raise ConnectionError("Couldn't connect to IBMQuantumExperience server: {0}"
# ---> 96                                   .format(ex)) from root_exception
#      97
#      98     @classmethod
#
# ConnectionError: Couldn't connect to IBMQuantumExperience server: error during login: 502 Server Error: Bad Gateway for url: https://quantumexperience.ng.bluemix.net/api/users/loginWithToken
