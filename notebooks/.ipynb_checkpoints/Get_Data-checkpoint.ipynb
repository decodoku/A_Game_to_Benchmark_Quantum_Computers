# %% [markdown]
# ## Set up and execute a calls to `GetData()` function

# %%
import sys
sys.path.append("../")
from devices import supportedDevices, getLayout
from QuantumAwesomeness import *

# %% [markdown]
# Specify the device you want to use (*device*) and whether you want data for a simulation, the real device, or both (*sims_to_use*).

# %%
device = 'ibmqx4'
sims_to_use = [False]

# %% [markdown]
# Get the data for the requested instances.

# %%
num, area, entangleType, pairs, pos, example, sdk, runs = getLayout(device)

for sim in sims_to_use:
    for move in runs[sim]['move']:
        for shots in runs[sim]['shots']:
            GetData( device, move, shots, sim, runs[sim]['samples'], runs[sim]['maxScore'] )
# Out:
# move=C, shots=8192, sample=1
# Status of device: {'available': True, 'pending_jobs': 10, 'name': 'ibmqx4'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-0727c33ecb04> in <module>()
#       4     for move in runs[sim]['move']:
#       5         for shots in runs[sim]['shots']:
# ----> 6             GetData( device, move, shots, sim, runs[sim]['samples'], runs[sim]['maxScore'] )
#
# /home/james/Dropbox/Work/Programming/A_Game_to_Benchmark_Quantum_Computers/QuantumAwesomeness.py in GetData(device, move, shots, sim, samples, maxScore)
#     879         print("move="+move+", shots="+str(shots)+", sample=" + str(sample+1) )
#     880
# --> 881         gates, conjugates, oneProbs, sameProbs, resultsDicts = runGame( device, move, shots, sim, maxScore )
#     882
#     883         # make a directory for this device if it doesn't already exist
#
# /home/james/Dropbox/Work/Programming/A_Game_to_Benchmark_Quantum_Computers/QuantumAwesomeness.py in runGame(device, move, shots, sim, maxScore, dataNeeded, clean, game)
#     676
#     677             # all gates so far are then run
# --> 678             oneProb, sameProb, results = entangle( device, move, shots, sim, gates, conjugates)
#     679
#     680         else:
#
# /home/james/Dropbox/Work/Programming/A_Game_to_Benchmark_Quantum_Computers/QuantumAwesomeness.py in entangle(device, move, shots, sim, gates, conjugates)
#     394
#     395
# --> 396     resultsRaw = getResults( device, sim, shots, q, c, engine, script )
#     397
#     398     oneProb, sameProb, results = processResults ( resultsRaw, num, pairs, sim, shots )
#
# /home/james/Dropbox/Work/Programming/A_Game_to_Benchmark_Quantum_Computers/QuantumAwesomeness.py in getResults(device, sim, shots, q, c, engine, script)
#     216                     print('Status of device:',backend.status)
#     217                 job = execute(script, backend, shots=shots, skip_translation=True)
# --> 218                 resultsVeryRaw = job.result().get_counts()
#     219                 noResults = False
#     220
#
# /home/james/anaconda3/lib/python3.6/site-packages/qiskit/backends/ibmq/ibmqjob.py in result(self, timeout, wait)
#      70         while self._status == JobStatus.INITIALIZING:
#      71             time.sleep(0.1)
# ---> 72         this_result = self._wait_for_job(timeout=timeout, wait=wait)
#      73         if self._is_device and self.done:
#      74             _reorder_bits(this_result)  # TODO: remove this after Qobj
#
# /home/james/anaconda3/lib/python3.6/site-packages/qiskit/backends/ibmq/ibmqjob.py in _wait_for_job(self, timeout, wait)
#     312             timer += wait
#     313             logger.info('status = %s (%d seconds)', api_result['status'], timer)
# --> 314             api_result = self._api.get_job(job_id)
#     315
#     316             if 'status' not in api_result:
#
# /home/james/anaconda3/lib/python3.6/site-packages/IBMQuantumExperience/IBMQuantumExperience.py in get_job(self, id_job, hub, group, project, access_token, user_id)
#     742         url += '/' + id_job
#     743
# --> 744         job = self.req.get(url)
#     745
#     746         # To remove result object and add the attributes to data object
#
# /home/james/anaconda3/lib/python3.6/site-packages/IBMQuantumExperience/IBMQuantumExperience.py in get(self, path, params, with_token)
#     361         while retries > 0:  # Repeat until no error
#     362             respond = requests.get(url, verify=self.verify, headers=headers,
# --> 363                                    **self.extra_args)
#     364             if not self.check_token(respond):
#     365                 respond = requests.get(url, verify=self.verify,
#
# /home/james/anaconda3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /home/james/anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /home/james/anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /home/james/anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /home/james/anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# /home/james/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# /home/james/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     344         # Trigger any extra validation we need to do.
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#     348             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /home/james/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     848         # Force connect early to allow us to validate the connection.
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#     852         if not conn.is_verified:
#
# /home/james/anaconda3/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     324             ca_cert_dir=self.ca_cert_dir,
#     325             server_hostname=hostname,
# --> 326             ssl_context=context)
#     327
#     328         if self.assert_fingerprint:
#
# /home/james/anaconda3/lib/python3.6/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     327         context.load_cert_chain(certfile, keyfile)
#     328     if HAS_SNI:  # Platform-specific: OpenSSL with enabled SNI
# --> 329         return context.wrap_socket(sock, server_hostname=server_hostname)
#     330
#     331     warnings.warn(
#
# /home/james/anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     439         while True:
#     440             try:
# --> 441                 cnx.do_handshake()
#     442             except OpenSSL.SSL.WantReadError:
#     443                 rd = util.wait_for_read(sock, sock.gettimeout())
#
# /home/james/anaconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1423         :return: None.
#    1424         """
# -> 1425         result = _lib.SSL_do_handshake(self._ssl)
#    1426         self._raise_ssl_error(self._ssl, result)
#    1427
#
# KeyboardInterrupt:
