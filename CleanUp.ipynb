# %% [markdown]
# This notebook is for those who know how to call the *CreateCleaningProfile* function directly.

# %%
from devices import *
from QuantumAwesomeness import *

# %%
CreateCleaningProfile ( '19Q-Acorn', 'C', 10000, False )
# Out:
# score =  1
# step = 0 , best fraction = 0.9166666666666665 , best difference = 0.09442460294645717
# step = 100 , best fraction = 0.9166666666666665 , best difference = 0.09248523236242831
# step = 200 , best fraction = 0.9166666666666665 , best difference = 0.09067688620456833
# step = 300 , best fraction = 0.9166666666666665 , best difference = 0.08925846870829068
# step = 400 , best fraction = 0.9166666666666665 , best difference = 0.08771682904581206
# step = 500 , best fraction = 0.923611111111111 , best difference = 0.08652275194051955
# step = 600 , best fraction = 0.923611111111111 , best difference = 0.08446550206506129
# step = 700 , best fraction = 0.923611111111111 , best difference = 0.08264619780892084
# step = 800 , best fraction = 0.923611111111111 , best difference = 0.08235368646670302
# step = 900 , best fraction = 0.9305555555555555 , best difference = 0.0824383650783511
# step = 1000 , best fraction = 0.9305555555555555 , best difference = 0.0808032490605003
# ...
