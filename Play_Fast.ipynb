# %% [markdown]
# This notebook is for those who know how to call the *runGame* function directly.

# %%
from devices import *
from QuantumAwesomeness import *
# %matplotlib inline

# %%
while True:
    runGame( 'ibmqx5', 'M', 8192, False, 0, dataNeeded=False)
# Out:
# Round 1
#
# Raw puzzle
# Cleaned puzzle
