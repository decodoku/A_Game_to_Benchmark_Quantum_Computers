# %% [markdown]
# This notebook is for those who know how to call the *runGame* function directly.

# %%
from devices import *
from QuantumAwesomeness import *
# %matplotlib inline

# %%
while True:
    sim = True
    maxScore = 10
    runGame( 'line5', 'M', 8192, sim, maxScore, dataNeeded=True, clean=(not sim) )
# Out:
# Round 2 complete
#
# Pairs you guessed for this round
# ['B', 'D']
# Pairs our bot would have guessed
# ['B', 'D']
# Correct pairs for this round
# ['B', 'D']
#
# You guessed 2 out of 2 pairs correctly!
#
#
# >Press Enter for the next round...
#
# Status of device: {'name': 'local_qasm_simulator_cpp', 'available': True}
#
# Round 3
