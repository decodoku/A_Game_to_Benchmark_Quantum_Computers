# %% [markdown]
# This notebook is for those who know how to call the *runGame* function directly.

# %%
from devices import *
from QuantumAwesomeness import *
# %matplotlib inline

# %%
while True:
    runGame( 'ibmqx2', 'M', 100, True, 0, dataNeeded=False)
# Out:
# Round 1
